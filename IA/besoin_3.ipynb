# %% [markdown]
# # Besoin 3 : Entraînement et Prédiction LSTM sur After_Sort.csv
#
# Ce notebook permet d'entraîner un modèle LSTM sur la base `db/After_Sort.csv` et de générer des prédictions, en s'appuyant sur les scripts Python existants.

# %% [markdown]
# ## 1. Installation des dépendances
#
# Assurez-vous d'utiliser Python 3.10 ou 3.11 pour la compatibilité avec TensorFlow.

# %%
# Installer les dépendances nécessaires (à exécuter une seule fois par environnement)
# !pip install tensorflow pandas numpy joblib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## 2. Entraînement du modèle LSTM
#
# Lance l'entraînement sur le fichier `db/After_Sort.csv` et sauvegarde les modèles dans le dossier `models_lstm_fast`.

# %%
# Entraînement du modèle LSTM (adapter le chemin si besoin)
# !python train_model.py --csv db/After_Sort.csv --models-dir models_lstm_fast --max-samples 10000
# Out:
# [INFO] 411723 lignes, 149 MMSI
#
# >> Horizon 5 min
# Train 10000 | Test 51672
# Epoch 1/20
#
#   1/157 ━━━━━━━━━━━━━━━━━━━━ 19:14 7s/step - loss: 0.8320 - mae: 0.7480
#   4/157 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.7974 - mae: 0.7263
#   8/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.7623 - mae: 0.7070
#  13/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.7203 - mae: 0.6848
#  16/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6965 - mae: 0.6717
#  20/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6640 - mae: 0.6527
#  25/157 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6270 - mae: 0.6296
#  29/157 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6002 - mae: 0.6119
#  33/157 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5754 - mae: 0.5948
#  38/157 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5473 - mae: 0.5748
#  42/157 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5268 - mae: 0.5597
#  47/157 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5034 - mae: 0.5421
# ...

# %% [markdown]
# ## 3. Prédiction des positions futures
#
# Utilise le modèle entraîné pour prédire les positions futures sur la même base.

# %%
# Prédiction des positions futures
# Vous pouvez limiter la mémoire utilisée en passant --max-pred-samples (ex: 1000) à la commande ci-dessous.
# !python predict_position.py --input db/After_Sort.csv --models-dir models_lstm_fast --output preds_after_sort.csv --max-pred-samples 1000
# Out:
# [INFO] Données chargées: 258102 lignes, 112 navires
# 2025-06-12 22:46:55.872851: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-12 22:46:58.214052: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Traceback (most recent call last):
#   File "c:\Users\Gauth\OneDrive\Documents\GitHub\Projet_Outil_de_l-ing-_S6\IA\predict_position.py", line 220, in <module>
#     main()
#   File "c:\Users\Gauth\OneDrive\Documents\GitHub\Projet_Outil_de_l-ing-_S6\IA\predict_position.py", line 167, in main
# ...

# %% [markdown]
# ## 4. Analyse et visualisation des résultats
#
# Chargement des prédictions et affichage d'un aperçu.

# %%
import pandas as pd

# Charger les prédictions
preds = pd.read_csv('preds_after_sort.csv')
preds.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 # Charger les prédictions
# ----> 4 preds = pd.read_csv('preds_after_sort.csv')
#       5 preds.head()
#
# ...
